# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
cd gdrive/MyDrive/Colab Notebooks/Fintech2022
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/Fintech2022

# %%
# !pip install -r requirements_4.txt #이 프로젝트를 하기 위해 설치해야 하는 library들이 requiremets에 들어있습니다.
# Out:
# Requirement already satisfied: dill==0.3.3 in /usr/local/lib/python3.7/dist-packages (from -r requirements_4.txt (line 1)) (0.3.3)
# Requirement already satisfied: pandas==1.1.5 in /usr/local/lib/python3.7/dist-packages (from -r requirements_4.txt (line 2)) (1.1.5)
# Requirement already satisfied: numpy==1.19.5 in /usr/local/lib/python3.7/dist-packages (from -r requirements_4.txt (line 3)) (1.19.5)
# Requirement already satisfied: scikit-learn==0.22.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements_4.txt (line 4)) (0.22.2)
# Requirement already satisfied: nltk==3.2.5 in /usr/local/lib/python3.7/dist-packages (from -r requirements_4.txt (line 5)) (3.2.5)
# Requirement already satisfied: torch==1.7.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements_4.txt (line 6)) (1.7.1)
# Requirement already satisfied: torchtext==0.3.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements_4.txt (line 7)) (0.3.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas==1.1.5->-r requirements_4.txt (line 2)) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas==1.1.5->-r requirements_4.txt (line 2)) (2018.9)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.22.2->-r requirements_4.txt (line 4)) (1.1.0)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.22.2->-r requirements_4.txt (line 4)) (1.4.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk==3.2.5->-r requirements_4.txt (line 5)) (1.15.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch==1.7.1->-r requirements_4.txt (line 6)) (3.10.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchtext==0.3.1->-r requirements_4.txt (line 7)) (2.23.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from torchtext==0.3.1->-r requirements_4.txt (line 7)) (4.63.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.3.1->-r requirements_4.txt (line 7)) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.3.1->-r requirements_4.txt (line 7)) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.3.1->-r requirements_4.txt (line 7)) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.3.1->-r requirements_4.txt (line 7)) (1.24.3)

# %%
import dill
import time
import random
import numpy as np
from sklearn.metrics import roc_curve, auc

import nltk

nltk.download("punkt")
from nltk.tokenize import word_tokenize

import torch
import torch.nn as nn

from torchtext.data import Field
from torchtext.data import TabularDataset
from torchtext.data import BucketIterator
from torchtext.data import Iterator
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
RANDOM_SEED = 2020
torch.manual_seed(RANDOM_SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(RANDOM_SEED)
random.seed(RANDOM_SEED)

# DATA_PATH = "data/processed/"
DATA_PATH = "/content/"

# %% [markdown]
# ## 데이터 불러오기
# - `torchtext.Field`를 이용해 각각의 필드를 정의해줍니다.

# %%
TEXT = Field(
    sequential=True,
    use_vocab=True,
    tokenize=word_tokenize,
    lower=True,
    batch_first=True,
)
LABEL = Field(
    sequential=False,
    use_vocab=False,
    batch_first=True,
)

# %% [markdown]
# 수능 데이터를 불러오는 코드입니다. `DATA_PATH`가 데이터가 있는 폴더로 정확히 입력되어 있는지 확인해주세요.

# %%
sat_train_data, sat_valid_data, sat_test_data = TabularDataset.splits(
    path="./data_project4/processed", #저는 현재 위치인 colab notebook 폴더에 data_project4 폴더 안에 porcessed라는 폴더를 넣었기 때문에 이렇게 path를 설정해 두었습니다.
    train="sat_train.tsv",
    validation="sat_valid.tsv",
    test="sat_test.tsv",
    format="tsv",
    fields=[("text", TEXT), ("label", LABEL)],
    skip_header=1,
)

sat_train_iterator, sat_valid_iterator, sat_test_iterator = BucketIterator.splits(
    (sat_train_data, sat_valid_data, sat_test_data),
    batch_size=8,
    device=None,
    sort=False,
)

TEXT.build_vocab(sat_train_data, min_freq=2)

# %% [markdown]
# ## LSTM Classifier

# %%
class LSTMClassifier(nn.Module):
    def __init__(self, num_embeddings, embedding_dim, hidden_size, num_layers, pad_idx):
        super().__init__()
        self.embed_layer = nn.Embedding(
            num_embeddings=num_embeddings,
            embedding_dim=embedding_dim,
            padding_idx=pad_idx
        )
        self.lstm_layer = nn.LSTM(
            input_size=embedding_dim,
            hidden_size=hidden_size,
            num_layers=num_layers,
            bidirectional=True,
            dropout=0.5
        )
        self.last_layer = nn.Sequential(
            nn.Linear(hidden_size * 2, hidden_size),
            nn.Dropout(0.5),
            nn.LeakyReLU(),
            nn.Linear(hidden_size, 1),
            nn.Sigmoid(),
        )

    def forward(self, x):
        embed_x = self.embed_layer(x)
        output, (_, _) = self.lstm_layer(embed_x)
        last_output = output[:, -1, :]
        last_output = self.last_layer(last_output)
        return last_output

# %% [markdown]
# Train, Evaluate, Test 를 정의합니다.

# %%
def train(model: nn.Module, iterator: Iterator, optimizer: torch.optim.Optimizer, criterion: nn.Module, device: str):
    model.train()
    epoch_loss = 0

    for _, batch in enumerate(iterator):
        optimizer.zero_grad()

        text = batch.text
        if text.shape[0] > 1:
            label = batch.label.type(torch.FloatTensor)
            text = text.to(device)
            label = label.to(device)
            output = model(text).flatten()
            loss = criterion(output, label)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()

    return epoch_loss / len(iterator)


def evaluate(model: nn.Module, iterator: Iterator, criterion: nn.Module, device: str):
    model.eval()
    epoch_loss = 0

    with torch.no_grad():
        for _, batch in enumerate(iterator):
            text = batch.text
            label = batch.label.type(torch.FloatTensor)
            text = text.to(device)
            label = label.to(device)
            output = model(text).flatten()
            loss = criterion(output, label)
            epoch_loss += loss.item()

    return epoch_loss / len(iterator)


def test(model: nn.Module, iterator: Iterator, device: str):
    model.eval()
    with torch.no_grad():
        y_real = []
        y_pred = []
        for batch in iterator:
            text = batch.text
            label = batch.label.type(torch.FloatTensor)
            text = text.to(device)
            output = model(text).flatten().cpu()
            y_real += [label]
            y_pred += [output]
        y_real = torch.cat(y_real)
        y_pred = torch.cat(y_pred)

    fpr, tpr, _ = roc_curve(y_real, y_pred)
    auroc = auc(fpr, tpr)

    return auroc


def epoch_time(start_time: int, end_time: int):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

# %% [markdown]
# ## 모델 학습하기

# %%
PAD_IDX = TEXT.vocab.stoi[TEXT.pad_token]
N_EPOCHS = 20

lstm_classifier = LSTMClassifier(
    num_embeddings=len(TEXT.vocab),
    embedding_dim=100,
    hidden_size=200,
    num_layers=4,
    pad_idx=PAD_IDX,
)
if torch.cuda.is_available():
    device = "cuda:0"
else:
    device = "cpu"
_ = lstm_classifier.to(device)

optimizer = torch.optim.Adam(lstm_classifier.parameters())
bce_loss_fn = nn.BCELoss()

for epoch in range(N_EPOCHS):

    start_time = time.time()

    train_loss = train(lstm_classifier, sat_train_iterator, optimizer, bce_loss_fn, device)
    valid_loss = evaluate(lstm_classifier, sat_valid_iterator, bce_loss_fn, device)

    end_time = time.time()

    epoch_mins, epoch_secs = epoch_time(start_time, end_time)

    print(f"Epoch: {epoch+1:02} | Time: {epoch_mins}m {epoch_secs}s")
    print(f"\tTrain Loss: {train_loss:.5f}")
    print(f"\t Val. Loss: {valid_loss:.5f}")
# Out:
# Epoch: 01 | Time: 0m 0s
# 	Train Loss: 0.51702
# 	 Val. Loss: 0.76741
# Epoch: 02 | Time: 0m 0s
# 	Train Loss: 0.51508
# 	 Val. Loss: 0.56001
# Epoch: 03 | Time: 0m 0s
# 	Train Loss: 0.47927
# 	 Val. Loss: 0.54225
# Epoch: 04 | Time: 0m 0s
# 	Train Loss: 0.43719
# 	 Val. Loss: 0.53417
# Epoch: 05 | Time: 0m 0s
# 	Train Loss: 0.42896
# 	 Val. Loss: 0.53441
# Epoch: 06 | Time: 0m 0s
# 	Train Loss: 0.40083
# 	 Val. Loss: 0.54588
# Epoch: 07 | Time: 0m 0s
# 	Train Loss: 0.43466
# 	 Val. Loss: 0.53869
# Epoch: 08 | Time: 0m 0s
# 	Train Loss: 0.42556
# 	 Val. Loss: 0.52977
# Epoch: 09 | Time: 0m 0s
# 	Train Loss: 0.41748
# 	 Val. Loss: 0.53601
# Epoch: 10 | Time: 0m 0s
# 	Train Loss: 0.43855
# 	 Val. Loss: 0.53276
# Epoch: 11 | Time: 0m 0s
# 	Train Loss: 0.43641
# 	 Val. Loss: 0.53342
# Epoch: 12 | Time: 0m 0s
# 	Train Loss: 0.46570
# 	 Val. Loss: 0.52786
# Epoch: 13 | Time: 0m 0s
# 	Train Loss: 0.43194
# 	 Val. Loss: 0.53692
# Epoch: 14 | Time: 0m 0s
# 	Train Loss: 0.41791
# 	 Val. Loss: 0.56046
# Epoch: 15 | Time: 0m 0s
# 	Train Loss: 0.42161
# 	 Val. Loss: 0.55100
# Epoch: 16 | Time: 0m 0s
# 	Train Loss: 0.41760
# 	 Val. Loss: 0.54441
# Epoch: 17 | Time: 0m 0s
# 	Train Loss: 0.43753
# 	 Val. Loss: 0.54469
# Epoch: 18 | Time: 0m 0s
# 	Train Loss: 0.44847
# 	 Val. Loss: 0.55420
# Epoch: 19 | Time: 0m 0s
# 	Train Loss: 0.43480
# 	 Val. Loss: 0.54724
# Epoch: 20 | Time: 0m 0s
# 	Train Loss: 0.42136
# 	 Val. Loss: 0.56120

# %%
_ = lstm_classifier.cpu()
test_auroc = test(lstm_classifier, sat_test_iterator, "cpu")

print(f"SAT Dataset Test AUROC: {test_auroc:.5f}")
# Out:
# SAT Dataset Test AUROC: 0.84615

# %%
with open("baseline_model.dill", "wb") as f:
    model = {
        "TEXT": TEXT,
        "LABEL": LABEL,
        "classifier": lstm_classifier
    }
    dill.dump(model, f)
